# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/2-Advance/FinRL_Ensemble_StockTrading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install wrds
# !pip install swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: wrds in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (3.1.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds) (1.23.5)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds) (2.2.3)
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds) (2.0.40)
# Requirement already satisfied: psycopg2-binary in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds) (2.9.9)
# Requirement already satisfied: mock in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pandas->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pandas->wrds) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pandas->wrds) (2025.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from sqlalchemy->wrds) (4.13.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->wrds) (1.17.0)
# Collecting swig
#   Downloading swig-4.3.0-py2.py3-none-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Downloading swig-4.3.0-py2.py3-none-macosx_10_9_universal2.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 13.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/q1/crm3rrkj7bqfbpx2j_0zk_qw0000gn/T/pip-req-build-vvo1jmgr
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/q1/crm3rrkj7bqfbpx2j_0zk_qw0000gn/T/pip-req-build-vvo1jmgr
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit fee71225ecfa3e9a6de228cf7269cd91718bb5c3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/q1/crm3rrkj7bqfbpx2j_0zk_qw0000gn/T/pip-install-cj98sr7o/elegantrl_b68ca21b6bf542dcad4a17c685553b36
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/q1/crm3rrkj7bqfbpx2j_0zk_qw0000gn/T/pip-install-cj98sr7o/elegantrl_b68ca21b6bf542dcad4a17c685553b36
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5e828af1503098f4da046c0f12432dbd4ef8bd97
#   Preparing metadata (setup.py) ... done
# Collecting alpaca-py<0.38,>=0.37 (from finrl==0.3.8)
#   Using cached alpaca_py-0.37.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from finrl==0.3.8) (3.2.0)
# Collecting ccxt<4,>=3 (from finrl==0.3.8)
#   Using cached ccxt-3.1.60-py2.py3-none-any.whl.metadata (108 kB)
# Requirement already satisfied: jqdatasdk<2,>=1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from finrl==0.3.8) (0.9.2)
# Collecting pyportfolioopt<2,>=1 (from finrl==0.3.8)
#   Using cached pyportfolioopt-1.5.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: ray<3,>=2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.44.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from finrl==0.3.8) (1.6.1)
# Collecting selenium<5,>=4 (from finrl==0.3.8)
#   Downloading selenium-4.30.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.8)
#   Using cached stockstats-0.5.4-py2.py3-none-any.whl.metadata (26 kB)
# Collecting webdriver-manager<5,>=4 (from finrl==0.3.8)
#   Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: wrds<4,>=3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from finrl==0.3.8) (3.1.1)
# Collecting yfinance<0.3,>=0.2 (from finrl==0.3.8)
#   Using cached yfinance-0.2.55-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.1)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.23.5)
# Requirement already satisfied: urllib3<2,>1.24 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.10.11)
# Requirement already satisfied: PyYAML==6.0.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ccxt<4,>=3->finrl==0.3.8) (75.8.2)
# Requirement already satisfied: certifi>=2018.1.18 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ccxt<4,>=3->finrl==0.3.8) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ccxt<4,>=3->finrl==0.3.8) (44.0.2)
# Requirement already satisfied: aiodns>=1.1.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ccxt<4,>=3->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ccxt<4,>=3->finrl==0.3.8) (1.18.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.40)
# Requirement already satisfied: pymysql>=0.7.6 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.2)
# Requirement already satisfied: ipython>=3.2.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.8) (8.18.1)
# Requirement already satisfied: matplotlib>=1.4.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.8) (3.9.4)
# Requirement already satisfied: pytz>=2014.10 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.8) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: seaborn>=0.7.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.8) (0.5.5)
# Collecting cvxpy>=1.1.19 (from pyportfolioopt<2,>=1->finrl==0.3.8)
#   Downloading cvxpy-1.6.4-cp39-cp39-macosx_10_9_universal2.whl.metadata (9.3 kB)
# Collecting ecos<3.0.0,>=2.0.14 (from pyportfolioopt<2,>=1->finrl==0.3.8)
#   Using cached ecos-2.0.14.tar.gz (142 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting numpy>=1.11.1 (from alpaca-trade-api<4,>=3->finrl==0.3.8)
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.1.8)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.18.0)
# Requirement already satisfied: jsonschema in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (6.30.2)
# Requirement already satisfied: aiosignal in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: frozenlist in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.5.0)
# Requirement already satisfied: aiohttp-cors in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.6)
# Requirement already satisfied: opencensus in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.21.1)
# Requirement already satisfied: smart-open in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.30.0)
# Requirement already satisfied: grpcio>=1.32.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.71.0)
# Requirement already satisfied: py-spy>=0.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.2.2)
# Collecting pyarrow>=9.0.0 (from ray[default,tune]<3,>=2->finrl==0.3.8)
#   Using cached pyarrow-19.0.1-cp39-cp39-macosx_12_0_arm64.whl.metadata (3.3 kB)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Collecting trio~=0.17 (from selenium<5,>=4->finrl==0.3.8)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium<5,>=4->finrl==0.3.8)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions~=4.9 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from selenium<5,>=4->finrl==0.3.8) (4.13.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.11.0.86)
# Requirement already satisfied: pygame in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.19.0)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (7.0.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (14.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.10.2)
# Requirement already satisfied: pillow in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.1.0)
# Collecting python-dotenv (from webdriver-manager<5,>=4->finrl==0.3.8)
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: psycopg2-binary in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.9)
# Requirement already satisfied: mock in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from wrds<4,>=3->finrl==0.3.8) (5.2.0)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.3.7)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.3)
# Collecting th (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8)
#   Using cached th-0.4.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: pycares>=4.0.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.3.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (5.0.1)
# Requirement already satisfied: importlib-metadata>=4.10.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ale-py>=0.9.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (8.6.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.6)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Collecting osqp>=0.6.2 (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8)
#   Downloading osqp-1.0.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting clarabel>=0.5.0 (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8)
#   Using cached clarabel-0.10.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (4.8 kB)
# Collecting scs>=3.2.4.post1 (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8)
#   Downloading scs-3.2.7.post2-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: pandas-datareader>=0.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (2.19.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: exceptiongroup in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (1.2.2)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (6.5.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pandas>=1.5.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: absl-py>=0.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Collecting sortedcontainers (from trio~=0.17->selenium<5,>=4->finrl==0.3.8)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting outcome (from trio~=0.17->selenium<5,>=4->finrl==0.3.8)
#   Using cached outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Collecting sniffio>=1.3.0 (from trio~=0.17->selenium<5,>=4->finrl==0.3.8)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8)
#   Using cached wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting PySocks!=1.5.7,<2.0,>=1.5.6 (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8)
#   Using cached PySocks-1.7.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.3.9)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from yarl>=1.7.2->ccxt<4,>=3->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.24.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.24.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: wrapt in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from smart-open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.2)
# Collecting niltype<2.0,>=0.3 (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8)
#   Using cached niltype-1.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.69.2)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.38.0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from importlib-metadata>=4.10.0->ale-py>=0.9.0->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.8) (5.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: executing>=1.2.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /opt/anaconda3/envs/rl-quant/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)
# Using cached alpaca_py-0.37.0-py3-none-any.whl (121 kB)
# Using cached ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
# Using cached pyportfolioopt-1.5.6-py3-none-any.whl (62 kB)
# Downloading selenium-4.30.0-py3-none-any.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 35.7 MB/s eta 0:00:00a 0:00:01
# Using cached stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Using cached webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Using cached yfinance-0.2.55-py2.py3-none-any.whl (109 kB)
# Downloading cvxpy-1.6.4-cp39-cp39-macosx_10_9_universal2.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.7 MB/s eta 0:00:0000:01
# Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Using cached pyarrow-19.0.1-cp39-cp39-macosx_12_0_arm64.whl (30.7 MB)
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 25.7 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Using cached th-0.4.1-py3-none-any.whl (12 kB)
# Using cached clarabel-0.10.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (1.7 MB)
# Using cached niltype-1.0.2-py3-none-any.whl (5.3 kB)
# Downloading osqp-1.0.3-cp39-cp39-macosx_11_0_arm64.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.2/289.2 kB 20.1 MB/s eta 0:00:00
# Using cached outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Downloading scs-3.2.7.post2-cp39-cp39-macosx_11_0_arm64.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.6/93.6 kB 12.8 MB/s eta 0:00:00
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wsproto-1.2.0-py3-none-any.whl (24 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Building wheels for collected packages: finrl, elegantrl, ecos
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.8-py3-none-any.whl size=4702673 sha256=d2dba959d5bc08f2c3ccbf4c4a89e5f8e9ab9f02d66306a649e584a3796f7577
#   Stored in directory: /private/var/folders/q1/crm3rrkj7bqfbpx2j_0zk_qw0000gn/T/pip-ephem-wheel-cache-ra6596o5/wheels/ec/6a/08/c43694890a7c5a62c23af4b2a497bce5ee7edef607852cf53f
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=elegantrl-0.3.10-py3-none-any.whl size=272056 sha256=061e6c0156e3a87c049257c8a9c515429cd6b1773cc8bd8ffaed2bc517145924
#   Stored in directory: /private/var/folders/q1/crm3rrkj7bqfbpx2j_0zk_qw0000gn/T/pip-ephem-wheel-cache-ra6596o5/wheels/a3/c3/be/03eb1f20c8650f23ab13b823d93a297a917899f5d08b04b7b9
#   Building wheel for ecos (pyproject.toml) ... done
#   Created wheel for ecos: filename=ecos-2.0.14-cp39-cp39-macosx_11_0_arm64.whl size=72599 sha256=3052d65804dc6442f5baaed616d731537dacbba2eae56992334bca297340c963
#   Stored in directory: /Users/wuminghan/Library/Caches/pip/wheels/88/68/07/e0e9fb25cbb17d151b57404b1f995954acd9a6fc1e020871fd
# Successfully built finrl elegantrl ecos
# Installing collected packages: sortedcontainers, sniffio, python-dotenv, PySocks, pyarrow, outcome, numpy, niltype, h11, wsproto, webdriver-manager, trio, th, yfinance, trio-websocket, stockstats, scs, osqp, ecos, clarabel, alpaca-py, selenium, elegantrl, cvxpy, ccxt, pyportfolioopt, finrl
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.1.72
#     Uninstalling yfinance-0.1.72:
#       Successfully uninstalled yfinance-0.1.72
#   Attempting uninstall: stockstats
#     Found existing installation: stockstats 0.4.1
#     Uninstalling stockstats-0.4.1:
#       Successfully uninstalled stockstats-0.4.1
#   Attempting uninstall: alpaca-py
#     Found existing installation: alpaca-py 0.39.1
#     Uninstalling alpaca-py-0.39.1:
#       Successfully uninstalled alpaca-py-0.39.1
#   Attempting uninstall: elegantrl
#     Found existing installation: elegantrl 0.3.6
#     Uninstalling elegantrl-0.3.6:
#       Successfully uninstalled elegantrl-0.3.6
#   Attempting uninstall: ccxt
#     Found existing installation: ccxt 4.4.71
#     Uninstalling ccxt-4.4.71:
#       Successfully uninstalled ccxt-4.4.71
#   Attempting uninstall: finrl
#     Found existing installation: FinRL 0.3.7
#     Uninstalling FinRL-0.3.7:
#       Successfully uninstalled FinRL-0.3.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.56.4 requires numpy<1.24,>=1.18, but you have numpy 2.0.2 which is incompatible.
# Successfully installed PySocks-1.7.1 alpaca-py-0.37.0 ccxt-3.1.60 clarabel-0.10.0 cvxpy-1.6.4 ecos-2.0.14 elegantrl-0.3.10 finrl-0.3.8 h11-0.14.0 niltype-1.0.2 numpy-2.0.2 osqp-1.0.3 outcome-1.3.0.post0 pyarrow-19.0.1 pyportfolioopt-1.5.6 python-dotenv-1.1.0 scs-3.2.7.post2 selenium-4.30.0 sniffio-1.3.1 sortedcontainers-2.4.0 stockstats-0.5.4 th-0.4.1 trio-0.29.0 trio-websocket-0.12.2 webdriver-manager-4.0.2 wsproto-1.2.0 yfinance-0.2.55

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)

check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
print(DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
# TRAIN_START_DATE = '2009-04-01'
# TRAIN_END_DATE = '2021-01-01'
# TEST_START_DATE = '2021-01-01'
# TEST_END_DATE = '2022-06-01'

TRAIN_START_DATE = '2010-01-01'
TRAIN_END_DATE = '2021-10-01'
TEST_START_DATE = '2021-10-01'
TEST_END_DATE = '2023-03-01'

df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TEST_END_DATE,
                     ticker_list = DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (97013, 8)

# %%
df.head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2010-01-04   6.440331   7.660714   7.585000   7.622500  493729600
# 1      2010-01-04  40.265980  57.869999  56.560001  56.630001    5277400
# 2      2010-01-04  32.828995  41.099998  40.389999  40.810001    6894300
# 3      2010-01-04  43.777546  56.389999  54.799999  55.720001    6186700
# 4      2010-01-04  39.738224  59.189999  57.509998  57.650002    7325600
#
# Price   tic  day
# 0      AAPL    0
# 1      AMGN    0
# 2       AXP    0
# 3        BA    0
# 4       CAT    0

# %%
df.tail()
# Out:
# Price        date       close        high         low        open    volume  \
# 97008  2023-02-28  459.688354  483.359985  473.920013  482.670013   3902100
# 97009  2023-02-28  216.611633  221.770004  219.500000  220.000000   5385400
# 97010  2023-02-28   33.829258   38.970001   38.549999   38.700001  16685300
# 97011  2023-02-28   31.044868   35.779999   35.320000   35.480000   8847000
# 97012  2023-02-28   45.985909   47.549999   46.983334   47.000000  18054000
#
# Price  tic  day
# 97008  UNH    1
# 97009    V    1
# 97010   VZ    1
# 97011  WBA    1
# 97012  WMT    1

# %%
df.shape
# Out:
# (97013, 8)

# %%
df.sort_values(['date','tic']).head()
# Out:
# Price        date      close       high        low       open     volume  \
# 0      2010-01-04   6.440331   7.660714   7.585000   7.622500  493729600
# 1      2010-01-04  40.265980  57.869999  56.560001  56.630001    5277400
# 2      2010-01-04  32.828995  41.099998  40.389999  40.810001    6894300
# 3      2010-01-04  43.777546  56.389999  54.799999  55.720001    6186700
# 4      2010-01-04  39.738224  59.189999  57.509998  57.650002    7325600
#
# Price   tic  day
# 0      AAPL    0
# 1      AMGN    0
# 2       AXP    0
# 3        BA    0
# 4       CAT    0

# %%
len(df.tic.unique())
# Out:
# 30

# %%
df.tic.value_counts()
# Out:
# tic
# AAPL    3311
# AMGN    3311
# WMT     3311
# WBA     3311
# VZ      3311
# V       3311
# UNH     3311
# TRV     3311
# PG      3311
# NKE     3311
# MSFT    3311
# MRK     3311
# MMM     3311
# MCD     3311
# KO      3311
# JPM     3311
# JNJ     3311
# INTC    3311
# IBM     3311
# HON     3311
# HD      3311
# GS      3311
# DIS     3311
# CVX     3311
# CSCO    3311
# CRM     3311
# CAT     3311
# BA      3311
# AXP     3311
# DOW      994
# Name: count, dtype: int64

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
#  INDICATORS = ['macd',
#                'rsi_30',
#                'cci_30',
#                'dx_30']

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df)
processed = processed.copy()
processed = processed.fillna(0)
processed = processed.replace(np.inf,0)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed.sample(5)
# Out:
#              date       close        high         low        open    volume  \
# 14791  2012-01-11   46.802551   66.449997   65.150002   65.260002   4960000
# 72194  2019-11-21   51.355396   58.299999   57.410000   57.490002  16139000
# 11825  2011-08-15   41.885330   61.959999   61.060001   61.869999  12111500
# 72842  2019-12-24  121.026299  136.449997  135.550003  136.449997    486200
# 77541  2020-08-17  299.100372  323.799988  319.350006  321.450012   2772500
#
#         tic  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 14791  AMGN    2  1.361271   47.999037   40.524008  67.446789  112.619951
# 72194  INTC    3  1.272356   52.201971   49.125953  64.985705   65.637847
# 11825    PG    0 -0.565481   44.131650   39.376715  47.437912  -41.690497
# 72842   TRV    1  0.407960  122.350971  119.064821  48.691807   60.881156
# 77541   UNH    0  5.530497  305.017425  273.858515  58.306978  141.545052
#
#            dx_30  close_30_sma  close_60_sma  turbulence
# 14791  41.134400     43.088639     41.450416   30.752068
# 72194  31.794487     48.985974     46.704427   15.731531
# 11825  23.178158     42.309057     42.949084   35.476166
# 72842   1.473090    120.178549    120.669749    3.225505
# 77541  48.171296    286.491537    281.585934   23.111937

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5
    
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

SAC_model_kwargs = {
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

TD3_model_kwargs = {
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000,
                  'sac' : 10_000,
                  'td3' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 SAC_model_kwargs,
                                                 TD3_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  201.71745101373335
# ======Model training from:  2010-01-01 to  2021-10-04
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_126_3
# ---------------------------------------
# | time/                 |             |
# |    fps                | 200         |
# |    iterations         | 100         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.239       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -38.8       |
# |    reward             | -0.15787628 |
# |    std                | 1           |
# |    value_loss         | 1.04        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 178       |
# |    iterations         | 200       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0874   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -38.1     |
# |    reward             | 0.8576754 |
# |    std                | 1.01      |
# |    value_loss         | 3.84      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 184        |
# |    iterations         | 300        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -38.5      |
# |    reward             | -2.9778316 |
# |    std                | 1.01       |
# |    value_loss         | 3.52       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 400       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | -0.0233   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 59.5      |
# |    reward             | 1.5386223 |
# |    std                | 1.01      |
# |    value_loss         | 5.41      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 183         |
# |    iterations         | 500         |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | -6.46       |
# |    reward             | -0.62258524 |
# |    std                | 1.01        |
# |    value_loss         | 3.73        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 600       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -0.725    |
# |    reward             | 1.3774685 |
# |    std                | 1.01      |
# |    value_loss         | 0.0855    |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 185       |
# |    iterations         | 700       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -2.52     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 29.7      |
# |    reward             | 0.6000619 |
# |    std                | 1.01      |
# |    value_loss         | 1.23      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 187        |
# |    iterations         | 800        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -0.0857    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -84        |
# |    reward             | 0.09333943 |
# |    std                | 1.01       |
# |    value_loss         | 4.09       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 190         |
# |    iterations         | 900         |
# |    time_elapsed       | 23          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | 0.116       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | -140        |
# |    reward             | 0.029449353 |
# |    std                | 1.01        |
# |    value_loss         | 10.9        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 191        |
# |    iterations         | 1000       |
# |    time_elapsed       | 26         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -395       |
# |    reward             | 0.19371168 |
# |    std                | 1.01       |
# |    value_loss         | 123        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 191       |
# |    iterations         | 1100      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -182      |
# |    reward             | 1.5567511 |
# |    std                | 1.01      |
# |    value_loss         | 20.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 191        |
# |    iterations         | 1200       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.0293     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -46.8      |
# |    reward             | -0.8470347 |
# |    std                | 1.01       |
# |    value_loss         | 2.15       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 191       |
# |    iterations         | 1300      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.189     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 19.5      |
# |    reward             | 0.8509302 |
# |    std                | 1.01      |
# |    value_loss         | 0.826     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 192        |
# |    iterations         | 1400       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 125        |
# |    reward             | -0.6068511 |
# |    std                | 1.01       |
# |    value_loss         | 11.6       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 193        |
# |    iterations         | 1500       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -102       |
# |    reward             | -4.0619473 |
# |    std                | 1.01       |
# |    value_loss         | 11.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 189       |
# |    iterations         | 1600      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -72.9     |
# |    reward             | 2.6021059 |
# |    std                | 1.01      |
# |    value_loss         | 23.5      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 1700     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -41.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -44.4    |
# |    reward             | 7.386162 |
# |    std                | 1.01     |
# |    value_loss         | 62.7     |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 189          |
# |    iterations         | 1800         |
# |    time_elapsed       | 47           |
# |    total_timesteps    | 9000         |
# | train/                |              |
# |    entropy_loss       | -41.5        |
# |    explained_variance | -0.0209      |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1799         |
# |    policy_loss        | -43.5        |
# |    reward             | -0.054393426 |
# |    std                | 1.01         |
# |    value_loss         | 2.08         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 190       |
# |    iterations         | 1900      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 33.2      |
# |    reward             | 1.1298927 |
# |    std                | 1.01      |
# |    value_loss         | 1.28      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 190        |
# |    iterations         | 2000       |
# |    time_elapsed       | 52         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 58.9       |
# |    reward             | 0.36964992 |
# |    std                | 1.01       |
# |    value_loss         | 2.26       |
# --------------------------------------
# ======a2c Validation from:  2021-10-04 to  2022-01-03
# a2c Sharpe Ratio:  0.1273917114975363
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_126_2
# day: 2957, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 5130044.76
# total_reward: 4130044.76
# total_cost: 5431.41
# total_trades: 51215
# Sharpe: 0.891
# =================================
# ======ddpg Validation from:  2021-10-04 to  2022-01-03
# ddpg Sharpe Ratio:  0.33644920179168547
# ======td3 Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_126_1
# day: 2957, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5974746.10
# total_reward: 4974746.10
# total_cost: 1294.70
# total_trades: 32608
# Sharpe: 0.945
# =================================
# ======td3 Validation from:  2021-10-04 to  2022-01-03
# td3 Sharpe Ratio:  0.435235835698633
# ======sac Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_126_1
# day: 2957, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 6601804.74
# total_reward: 5601804.74
# total_cost: 1181.86
# total_trades: 47335
# Sharpe: 1.004
# =================================
# ======sac Validation from:  2021-10-04 to  2022-01-03
# sac Sharpe Ratio:  0.30250610669934497
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_126_1
# ----------------------------------
# | time/              |           |
# |    fps             | 222       |
# |    iterations      | 1         |
# |    time_elapsed    | 9         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.5730172 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012166189 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0385     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.42        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.025      |
# |    reward               | 1.1826903   |
# |    std                  | 1           |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 210          |
# |    iterations           | 3            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.013018709  |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.2        |
# |    explained_variance   | -0.00351     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 15.1         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0162      |
# |    reward               | -0.080568746 |
# |    std                  | 1            |
# |    value_loss           | 42.1         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 217        |
# |    iterations           | 4          |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01830383 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00446   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 49.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0213    |
# |    reward               | 3.5456586  |
# |    std                  | 1          |
# |    value_loss           | 62.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 222         |
# |    iterations           | 5           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018185522 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0294     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.55        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0232     |
# |    reward               | -0.15036741 |
# |    std                  | 1.01        |
# |    value_loss           | 15.6        |
# -----------------------------------------
# ======ppo Validation from:  2021-10-04 to  2022-01-03
# ppo Sharpe Ratio:  0.17830064147256242
# ======Best Model Retraining from:  2010-01-01 to  2022-01-03
# ======Trading from:  2022-01-03 to  2022-04-04
# ============================================
# turbulence_threshold:  201.71745101373335
# ======Model training from:  2010-01-01 to  2022-01-03
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_189_1
# --------------------------------------
# | time/                 |            |
# |    fps                | 200        |
# |    iterations         | 100        |
# |    time_elapsed       | 2          |
# |    total_timesteps    | 500        |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.315     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 99         |
# |    policy_loss        | -2.04      |
# |    reward             | 0.14814144 |
# |    std                | 1          |
# |    value_loss         | 0.747      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 200       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.11     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -63.6     |
# |    reward             | 0.7431739 |
# |    std                | 1         |
# |    value_loss         | 6.51      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 192        |
# |    iterations         | 300        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.0133    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -89.3      |
# |    reward             | -3.4319425 |
# |    std                | 1          |
# |    value_loss         | 11.6       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 191       |
# |    iterations         | 400       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 90.2      |
# |    reward             | 1.1037041 |
# |    std                | 1         |
# |    value_loss         | 14.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 191        |
# |    iterations         | 500        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -21.5      |
# |    reward             | -1.0708085 |
# |    std                | 1          |
# |    value_loss         | 2.96       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 189       |
# |    iterations         | 600       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -139      |
# |    reward             | 12.211676 |
# |    std                | 1         |
# |    value_loss         | 26.6      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 184         |
# |    iterations         | 700         |
# |    time_elapsed       | 19          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | -107        |
# |    reward             | -0.34351927 |
# |    std                | 1           |
# |    value_loss         | 8.31        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 800       |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.596    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 86.4      |
# |    reward             | 0.5289902 |
# |    std                | 1         |
# |    value_loss         | 5.1       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 184      |
# |    iterations         | 900      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -50.5    |
# |    reward             | 0.530429 |
# |    std                | 1        |
# |    value_loss         | 2.68     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 1000      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 34.7      |
# |    reward             | 0.8076915 |
# |    std                | 1         |
# |    value_loss         | 1.87      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 183       |
# |    iterations         | 1100      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -26.1     |
# |    reward             | 0.6039699 |
# |    std                | 1         |
# |    value_loss         | 5.17      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 183      |
# |    iterations         | 1200     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 177      |
# |    reward             | 1.12893  |
# |    std                | 1        |
# |    value_loss         | 33.5     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 184       |
# |    iterations         | 1300      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.00472   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -47.1     |
# |    reward             | 1.5652993 |
# |    std                | 1         |
# |    value_loss         | 1.79      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 185        |
# |    iterations         | 1400       |
# |    time_elapsed       | 37         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 145        |
# |    reward             | -1.0691205 |
# |    std                | 1          |
# |    value_loss         | 19.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 182       |
# |    iterations         | 1500      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 256       |
# |    reward             | 3.9649782 |
# |    std                | 1         |
# |    value_loss         | 42.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 181        |
# |    iterations         | 1600       |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.511      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 100        |
# |    reward             | -1.4328605 |
# |    std                | 1          |
# |    value_loss         | 6.16       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 180       |
# |    iterations         | 1700      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -707      |
# |    reward             | 6.1170483 |
# |    std                | 1         |
# |    value_loss         | 262       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 180        |
# |    iterations         | 1800       |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.00826    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 481        |
# |    reward             | -13.602508 |
# |    std                | 1          |
# |    value_loss         | 272        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 180       |
# |    iterations         | 1900      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 52.7      |
# |    reward             | 0.9850979 |
# |    std                | 1         |
# |    value_loss         | 4.35      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 181        |
# |    iterations         | 2000       |
# |    time_elapsed       | 55         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.135     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 143        |
# |    reward             | -1.6706848 |
# |    std                | 1          |
# |    value_loss         | 12.2       |
# --------------------------------------
# ======a2c Validation from:  2022-01-03 to  2022-04-04
# a2c Sharpe Ratio:  -0.1651011437539034
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_189_1
# day: 3020, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 4995093.31
# total_reward: 3995093.31
# total_cost: 6337.35
# total_trades: 46601
# Sharpe: 0.875
# =================================
# ======ddpg Validation from:  2022-01-03 to  2022-04-04
# ddpg Sharpe Ratio:  -0.2880979598996818
# ======td3 Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_189_1
# day: 3020, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7403859.24
# total_reward: 6403859.24
# total_cost: 1309.96
# total_trades: 49872
# Sharpe: 1.036
# =================================
# ======td3 Validation from:  2022-01-03 to  2022-04-04
# td3 Sharpe Ratio:  -0.10023605320322865
# ======sac Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_189_1
# day: 3020, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 4871653.96
# total_reward: 3871653.96
# total_cost: 1386.54
# total_trades: 30332
# Sharpe: 0.747
# =================================
# ======sac Validation from:  2022-01-03 to  2022-04-04
# sac Sharpe Ratio:  -0.32743473774163157
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_189_1
# ----------------------------------
# | time/              |           |
# |    fps             | 241       |
# |    iterations      | 1         |
# |    time_elapsed    | 8         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.0782807 |
# ----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 236         |
# |    iterations           | 2           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015898503 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00121     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.59        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | -2.2154682  |
# |    std                  | 1           |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 3           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012547903 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | 0.00572     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    reward               | -0.39400905 |
# |    std                  | 1           |
# |    value_loss           | 40.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 4           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015195126 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00641    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -1.0914224  |
# |    std                  | 1           |
# |    value_loss           | 68.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 238         |
# |    iterations           | 5           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.016248938 |
# |    clip_fraction        | 0.194       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0125     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 4.67        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0222     |
# |    reward               | -0.19160593 |
# |    std                  | 1.01        |
# |    value_loss           | 12.7        |
# -----------------------------------------
# ======ppo Validation from:  2022-01-03 to  2022-04-04
# ppo Sharpe Ratio:  -0.05119985005399678
# ======Best Model Retraining from:  2010-01-01 to  2022-04-04
# ======Trading from:  2022-04-04 to  2022-07-06
# ============================================
# turbulence_threshold:  201.71745101373335
# ======Model training from:  2010-01-01 to  2022-04-04
# ======a2c Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cpu device
# Logging to tensorboard_log/a2c/a2c_252_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 208       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.309    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -86.4     |
# |    reward             | 0.5548888 |
# |    std                | 1         |
# |    value_loss         | 5.86      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 209        |
# |    iterations         | 200        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0484     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 11.6       |
# |    reward             | 0.49712497 |
# |    std                | 1          |
# |    value_loss         | 2.73       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 200       |
# |    iterations         | 300       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0322   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -104      |
# |    reward             | -3.574737 |
# |    std                | 1         |
# |    value_loss         | 13.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 198       |
# |    iterations         | 400       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0513   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -84.5     |
# |    reward             | 1.0465641 |
# |    std                | 1         |
# |    value_loss         | 10.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 199       |
# |    iterations         | 500       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -146      |
# |    reward             | 1.1620843 |
# |    std                | 1         |
# |    value_loss         | 25.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 199       |
# |    iterations         | 600       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 233       |
# |    reward             | 7.6816154 |
# |    std                | 1         |
# |    value_loss         | 36.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 700      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0.00597  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -233     |
# |    reward             | 2.019534 |
# |    std                | 1        |
# |    value_loss         | 37.3     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 800        |
# |    time_elapsed       | 20         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.00356    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -176       |
# |    reward             | 0.36450753 |
# |    std                | 1          |
# |    value_loss         | 23.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 194        |
# |    iterations         | 900        |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -80.9      |
# |    reward             | -2.2490692 |
# |    std                | 1          |
# |    value_loss         | 7.97       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 195       |
# |    iterations         | 1000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0.0165    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | 130       |
# |    reward             | 3.8397934 |
# |    std                | 1         |
# |    value_loss         | 13.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 195        |
# |    iterations         | 1100       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | -485       |
# |    reward             | -1.5093307 |
# |    std                | 1          |
# |    value_loss         | 194        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 195        |
# |    iterations         | 1200       |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -251       |
# |    reward             | -1.2862744 |
# |    std                | 1          |
# |    value_loss         | 96.8       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 194        |
# |    iterations         | 1300       |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -0.148     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 114        |
# |    reward             | 0.47853017 |
# |    std                | 1          |
# |    value_loss         | 8.36       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 193       |
# |    iterations         | 1400      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -119      |
# |    reward             | 1.4044768 |
# |    std                | 1         |
# |    value_loss         | 10.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 191      |
# |    iterations         | 1500     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -136     |
# |    reward             | 2.081582 |
# |    std                | 1.01     |
# |    value_loss         | 9.25     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 189        |
# |    iterations         | 1600       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 24.2       |
# |    reward             | 0.05999914 |
# |    std                | 1          |
# |    value_loss         | 0.687      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 187       |
# |    iterations         | 1700      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 240       |
# |    reward             | 3.5391343 |
# |    std                | 1         |
# |    value_loss         | 49.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 186        |
# |    iterations         | 1800       |
# |    time_elapsed       | 48         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 765        |
# |    reward             | -1.4610198 |
# |    std                | 1.01       |
# |    value_loss         | 437        |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 186          |
# |    iterations         | 1900         |
# |    time_elapsed       | 51           |
# |    total_timesteps    | 9500         |
# | train/                |              |
# |    entropy_loss       | -41.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1899         |
# ...
# |    fps                | 198       |
# |    iterations         | 400       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.000231 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 46.8      |
# |    reward             | 4.8900127 |
# |    std                | 0.997     |
# |    value_loss         | 10.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 500        |
# |    time_elapsed       | 12         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -106       |
# |    reward             | -2.3230138 |
# |    std                | 0.994      |
# |    value_loss         | 11.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 600        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | 0.00274    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 359        |
# |    reward             | 13.7314625 |
# |    std                | 0.994      |
# |    value_loss         | 132        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 700      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | -0.69    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -61.4    |
# |    reward             | 0.878836 |
# |    std                | 0.994    |
# |    value_loss         | 2.15     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 198       |
# |    iterations         | 800       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 88.3      |
# |    reward             | 0.8725244 |
# |    std                | 0.994     |
# |    value_loss         | 5.65      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 198        |
# |    iterations         | 900        |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 6.52       |
# |    reward             | 0.15709306 |
# |    std                | 0.993      |
# |    value_loss         | 2.9        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 197       |
# |    iterations         | 1000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -40.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -39.2     |
# |    reward             | 2.0494325 |
# |    std                | 0.991     |
# |    value_loss         | 2.12      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 197         |
# |    iterations         | 1100        |
# |    time_elapsed       | 27          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -40.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 85.9        |
# |    reward             | -0.98100436 |
# |    std                | 0.991       |
# |    value_loss         | 6.34        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 197         |
# |    iterations         | 1200        |
# |    time_elapsed       | 30          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -40.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | 25.7        |
# |    reward             | -0.43825284 |
# |    std                | 0.992       |
# |    value_loss         | 4.26        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 197         |
# |    iterations         | 1300        |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 6500        |
# | train/                |             |
# |    entropy_loss       | -40.9       |
# |    explained_variance | -0.0918     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1299        |
# |    policy_loss        | 4.94        |
# |    reward             | -0.08944722 |
# |    std                | 0.993       |
# |    value_loss         | 0.436       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 196        |
# |    iterations         | 1400       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | -36.2      |
# |    reward             | -2.0364978 |
# |    std                | 0.994      |
# |    value_loss         | 3.21       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 195       |
# |    iterations         | 1500      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -63.4     |
# |    reward             | 2.0571933 |
# |    std                | 0.994     |
# |    value_loss         | 4.7       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 194        |
# |    iterations         | 1600       |
# |    time_elapsed       | 41         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -23.1      |
# |    reward             | -0.2773486 |
# |    std                | 0.993      |
# |    value_loss         | 1.06       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 192          |
# |    iterations         | 1700         |
# |    time_elapsed       | 44           |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -40.9        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | 92.5         |
# |    reward             | -0.053156864 |
# |    std                | 0.992        |
# |    value_loss         | 5.21         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 190        |
# |    iterations         | 1800       |
# |    time_elapsed       | 47         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -40.9      |
# |    explained_variance | -0.135     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | 8.65       |
# |    reward             | 0.11229453 |
# |    std                | 0.993      |
# |    value_loss         | 6.98       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 188        |
# |    iterations         | 1900       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | -0.216     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 33.8       |
# |    reward             | 0.18041809 |
# |    std                | 0.994      |
# |    value_loss         | 0.72       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 186      |
# |    iterations         | 2000     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 114      |
# |    reward             | 0.259812 |
# |    std                | 0.994    |
# |    value_loss         | 9.91     |
# ------------------------------------
# ======a2c Validation from:  2022-07-06 to  2022-10-04
# a2c Sharpe Ratio:  -0.1753965716799133
# ======ddpg Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/ddpg/ddpg_315_1
# day: 3146, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 7152299.87
# total_reward: 6152299.87
# total_cost: 5770.77
# total_trades: 41163
# Sharpe: 0.979
# =================================
# ======ddpg Validation from:  2022-07-06 to  2022-10-04
# ddpg Sharpe Ratio:  -0.17405328727205688
# ======td3 Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/td3/td3_315_1
# day: 3146, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 4449974.40
# total_reward: 3449974.40
# total_cost: 1390.61
# total_trades: 37910
# Sharpe: 0.737
# =================================
# ======td3 Validation from:  2022-07-06 to  2022-10-04
# td3 Sharpe Ratio:  -0.0464110642061594
# ======sac Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 64}
# Using cpu device
# Logging to tensorboard_log/sac/sac_315_1
# day: 3146, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 2635338.81
# total_reward: 1635338.81
# total_cost: 119340.39
# total_trades: 74449
# Sharpe: 0.412
# =================================
# ======sac Validation from:  2022-07-06 to  2022-10-04
# sac Sharpe Ratio:  -0.15232448105346152
# ======ppo Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to tensorboard_log/ppo/ppo_315_1
# ---------------------------------
# | time/              |          |
# |    fps             | 212      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    reward          | 0.515874 |
# ---------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 225         |
# |    iterations           | 2           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.017599992 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0451     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.36        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0266     |
# |    reward               | 3.603315    |
# |    std                  | 1           |
# |    value_loss           | 9.5         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 228         |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014282754 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0128     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0142     |
# |    reward               | 2.13755     |
# |    std                  | 1.01        |
# |    value_loss           | 45.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 229         |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.018296314 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.0108     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.3        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0143     |
# |    reward               | 1.4875774   |
# |    std                  | 1.01        |
# |    value_loss           | 68.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 227         |
# |    iterations           | 5           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.02630706  |
# |    clip_fraction        | 0.243       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00217    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 8.18        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0186     |
# |    reward               | -0.22136718 |
# |    std                  | 1.01        |
# |    value_loss           | 21.8        |
# -----------------------------------------
# ======ppo Validation from:  2022-07-06 to  2022-10-04
# ppo Sharpe Ratio:  -0.2549502840958593
# ======Best Model Retraining from:  2010-01-01 to  2022-10-04
# ======Trading from:  2022-10-04 to  2023-01-04
# Ensemble Strategy took:  27.112201682726543  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe  \
# 0  126  2021-10-04  2022-01-03        TD3   0.127392   0.178301    0.336449
# 1  189  2022-01-03  2022-04-04        PPO  -0.165101    -0.0512   -0.288098
# 2  252  2022-04-04  2022-07-06        A2C   -0.15813  -0.233201   -0.227224
# 3  315  2022-07-06  2022-10-04        TD3  -0.175397   -0.25495   -0.174053
#
#   SAC Sharpe TD3 Sharpe
# 0   0.302506   0.435236
# 1  -0.327435  -0.100236
# 2  -0.190971  -0.183553
# 3  -0.152324  -0.046411

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = pd.concat([df_account_value, temp], ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# Out:
# Sharpe Ratio:  -0.4502857179318782

# %%
df_account_value.head()
# Out:
#    account_value        date  daily_return    datadate
# 0   1.000000e+06  2022-01-03           NaN  2022-01-03
# 1   1.000971e+06  2022-01-04      0.000971  2022-01-04
# 2   9.984110e+05  2022-01-05     -0.002557  2022-01-05
# 3   9.908559e+05  2022-01-06     -0.007567  2022-01-06
# 4   9.853229e+05  2022-01-07     -0.005584  2022-01-07

# %%
# %matplotlib inline
df_account_value.account_value.plot()
# Out:
# <Axes: >

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.107684
# Cumulative returns    -0.107684
# Annual volatility      0.206770
# Sharpe ratio          -0.450286
# Calmar ratio          -0.538166
# Stability              0.265733
# Max drawdown          -0.200094
# Omega ratio            0.926348
# Sortino ratio         -0.642432
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.040262
# Daily value at risk   -0.026420
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
df_dji_ = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(df_dji_, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (251, 8)
# Annual return         -0.094324
# Cumulative returns    -0.093968
# Annual volatility      0.198502
# Sharpe ratio          -0.402058
# Calmar ratio          -0.429901
# Stability              0.236972
# Max drawdown          -0.219408
# Omega ratio            0.936015
# Sortino ratio         -0.559755
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.014390
# Daily value at risk   -0.025326
# dtype: float64

# %%
df_dji = pd.DataFrame()
df_dji['date'] = df_account_value['date']
df_dji['dji'] = df_dji_['close'] / df_dji_['close'][0] * env_kwargs["initial_amount"]
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji.csv")
df_dji = df_dji.set_index(df_dji.columns[0])
print("df_dji: ", df_dji)
df_dji.to_csv("df_dji+.csv")

df_account_value.to_csv('df_account_value.csv')
# Out:
# df_dji:             date           dji
# 0    2022-01-03  1.000000e+06
# 1    2022-01-04  1.005866e+06
# 2    2022-01-05  9.951360e+05
# 3    2022-01-06  9.904718e+05
# 4    2022-01-07  9.903404e+05
# ..          ...           ...
# 247  2022-12-27  9.086102e+05
# 248  2022-12-28  8.986103e+05
# 249  2022-12-29  9.080428e+05
# 250  2022-12-30  9.060324e+05
# 251  2023-01-03           NaN
#
# [252 rows x 2 columns]
# df_dji:                       dji
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.005866e+06
# 2022-01-05  9.951360e+05
# 2022-01-06  9.904718e+05
# 2022-01-07  9.903404e+05
# ...                  ...
# 2022-12-27  9.086102e+05
# 2022-12-28  8.986103e+05
# 2022-12-29  9.080428e+05
# 2022-12-30  9.060324e+05
# 2023-01-03           NaN
#
# [252 rows x 1 columns]

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
# print("==============Compare to DJIA===========")
# %matplotlib inline
# # S&P 500: ^GSPC
# # Dow Jones Index: ^DJI
# # NASDAQ 100: ^NDX
# backtest_plot(df_account_value, 
#               baseline_ticker = '^DJI', 
#               baseline_start = df_account_value.loc[0,'date'],
#               baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
df.to_csv("df.csv")
df_result_ensemble = pd.DataFrame({'date': df_account_value['date'], 'ensemble': df_account_value['account_value']})
df_result_ensemble = df_result_ensemble.set_index('date')

print("df_result_ensemble.columns: ", df_result_ensemble.columns)

# df_result_ensemble.drop(df_result_ensemble.columns[0], axis = 1)
print("df_trade_date: ", df_trade_date)
# df_result_ensemble['date'] = df_trade_date['datadate']
# df_result_ensemble['account_value'] = df_account_value['account_value']
df_result_ensemble.to_csv("df_result_ensemble.csv")
print("df_result_ensemble: ", df_result_ensemble)
print("==============Compare to DJIA===========")
result = pd.DataFrame()
# result = pd.merge(result, df_result_ensemble, left_index=True, right_index=True)
# result = pd.merge(result, df_dji, left_index=True, right_index=True)
result = pd.merge(df_result_ensemble, df_dji, left_index=True, right_index=True)
print("result: ", result)
result.to_csv("result.csv")
result.columns = ['ensemble', 'dji']

# %matplotlib inline
plt.rcParams["figure.figsize"] = (15,5)
plt.figure();
result.plot();
# Out:
# df_result_ensemble.columns:  Index(['ensemble'], dtype='object')
# df_trade_date:         datadate
# 0    2021-10-04
# 1    2021-10-05
# 2    2021-10-06
# 3    2021-10-07
# 4    2021-10-08
# ..          ...
# 348  2023-02-22
# 349  2023-02-23
# 350  2023-02-24
# 351  2023-02-27
# 352  2023-02-28
#
# [353 rows x 1 columns]
# df_result_ensemble:                  ensemble
# date
# 2022-01-03  1.000000e+06
# 2022-01-04  1.000971e+06
# 2022-01-05  9.984110e+05
# 2022-01-06  9.908559e+05
# 2022-01-07  9.853229e+05
# ...                  ...
# 2022-12-27  9.010279e+05
# 2022-12-28  8.861087e+05
# 2022-12-29  9.003022e+05
# 2022-12-30  8.991574e+05
# 2023-01-03  8.923160e+05
#
# [252 rows x 1 columns]
# ==============Compare to DJIA===========
# result:                  ensemble           dji
# date
# 2022-01-03  1.000000e+06  1.000000e+06
# 2022-01-04  1.000971e+06  1.005866e+06
# 2022-01-05  9.984110e+05  9.951360e+05
# 2022-01-06  9.908559e+05  9.904718e+05
# 2022-01-07  9.853229e+05  9.903404e+05
# ...                  ...           ...
# 2022-12-27  9.010279e+05  9.086102e+05
# 2022-12-28  8.861087e+05  8.986103e+05
# 2022-12-29  9.003022e+05  9.080428e+05
# 2022-12-30  8.991574e+05  9.060324e+05
# 2023-01-03  8.923160e+05           NaN
#
# [252 rows x 2 columns]
